# %% [markdown]
# <a href="https://colab.research.google.com/github/hetalsharmaaa/perzonix/blob/main/LaptopRecommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pandas numpy scikit-learn scipy matplotlib seaborn

# %%
import pandas as pd
import numpy as np

# %%
laptops_clean   = pd.read_csv("/content/laptops_cleaned.csv")
laptops_unclean = pd.read_csv("/content/laptops_uncleaned.csv")

# %%
print("=" * 60)
print("LAPTOPS — CLEANED VERSION")
print("=" * 60)
print(f"Rows: {laptops_clean.shape[0]}   Columns: {laptops_clean.shape[1]}")
print("\nColumn names and types:")
print(laptops_clean.dtypes)
print("\nFirst 5 rows:")
print(laptops_clean.head())
# Out:
# ...
# LAPTOPS — CLEANED VERSION
# ...
# Rows: 1018   Columns: 22
#
# Column names and types:
# index                   int64
# brand_name             object
# model                  object
# price                   int64
# rating                float64
# processor              object
# processor_brand        object
# iter                   object
# ram                    object
# threads_num           float64
# core_num              float64
# ram_num                 int64
# memory_type            object
# memory_size             int64
# gpu_brand              object
# gpu_type               object
# os                     object
# display_size          float64
# resolutioin_height      int64
# resolutioin_width       int64
# Touch_Screen             bool
# warrenty                int64
# dtype: object
#
# First 5 rows:
#    index brand_name                                              model  \
# 0      2     Lenovo  Lenovo V15 G4 ‎83CR000VIN Laptop (AMD Ryzen 7 ...
# ...

# %%
print("\n" + "=" * 60)
print("LAPTOPS — UNCLEANED VERSION")
print("=" * 60)
print(f"Rows: {laptops_unclean.shape[0]}   Columns: {laptops_unclean.shape[1]}")
print("\nColumn names and types:")
print(laptops_unclean.dtypes)
print("\nFirst 5 rows:")
print(laptops_unclean.head())
# Out:
# ...
# LAPTOPS — UNCLEANED VERSION
# ...
# Rows: 1020   Columns: 12
#
# Column names and types:
# Unnamed: 0        int64
# model            object
# price            object
# rating          float64
# processor        object
# core             object
# ram              object
# memory           object
# graphic_card     object
# display          object
# os               object
# warrenty         object
# dtype: object
#
# First 5 rows:
#    Unnamed: 0                                              model      price  \
# 0           0  Lenovo V15 G4 ‎83CR000VIN Laptop (AMD Ryzen 7 ...    ₹39,990
# 1           1  Samsung Galaxy Book 4 NP750XGJ-LG4IN Laptop (1...    ₹36,990
# 2           2  HP 15-fc0154AU Laptop (AMD Ryzen 3 7320U/ 8GB/...    ₹30,290
# 3           3  MSI Titan 18 HX Gaming Laptop (Intel Core Ultr...  ₹3,59,900
# 4           4  Asus Vivobook 16X 2023 K3605ZC-MBN544WS Laptop...    ₹59,140
#
#    rating                      processor                             core  \
# ...

# %%
print("\n" + "=" * 60)
print("MISSING VALUES — LAPTOPS CLEANED")
print("=" * 60)
missing_clean = laptops_clean.isnull().sum()
missing_clean_pct = (missing_clean / len(laptops_clean) * 100).round(1)
missing_clean_df = pd.DataFrame({
    "Missing Count": missing_clean,
    "Missing %": missing_clean_pct
})
print(missing_clean_df[missing_clean_df["Missing Count"] > 0])
# Out:
# ...
# MISSING VALUES — LAPTOPS CLEANED
# ...
#              Missing Count  Missing %
# threads_num             77        7.6
# core_num                22        2.2

# %%
print("\n" + "=" * 60)
print("MISSING VALUES — LAPTOPS UNCLEANED")
print("=" * 60)
missing_unclean = laptops_unclean.isnull().sum()
missing_unclean_pct = (missing_unclean / len(laptops_unclean) * 100).round(1)
missing_unclean_df = pd.DataFrame({
    "Missing Count": missing_unclean,
    "Missing %": missing_unclean_pct
})
print(missing_unclean_df[missing_unclean_df["Missing Count"] > 0])
# Out:
# ...
# MISSING VALUES — LAPTOPS UNCLEANED
# ...
#           Missing Count  Missing %
# warrenty              3        0.3

# %%
print("\n" + "=" * 60)
print("STATISTICS — LAPTOPS CLEANED (numeric columns)")
print("=" * 60)
print(laptops_clean.describe())
# Out:
# ...
# STATISTICS — LAPTOPS CLEANED (numeric columns)
# ...
#              index          price       rating  threads_num    core_num  \
# count  1018.000000    1018.000000  1018.000000    941.00000  996.000000
# mean    512.326130   89266.192534     4.360511     14.34644   10.706827
# std     294.290627   72477.867661     0.232621      6.40504    4.057922
# min       2.000000   10990.000000     4.000000      2.00000    5.000000
# 25%     258.250000   46899.000000     4.150000     12.00000    8.000000
# 50%     512.500000   67590.000000     4.350000     12.00000    9.000000
# 75%     766.750000   99996.750000     4.550000     16.00000   12.000000
# max    1021.000000  500990.000000     4.750000     32.00000   24.000000
#
#            ram_num  memory_size  display_size  resolutioin_height  \
# count  1018.000000  1018.000000   1018.000000         1018.000000
# mean     16.119843   674.388998     15.208694         2085.155206
# std       8.440979   370.005328      0.981107          444.962753
# ...

# %%
print("\n" + "=" * 60)
print("UNIQUE VALUES IN KEY COLUMNS — LAPTOPS CLEANED")
print("=" * 60)
for col in laptops_clean.select_dtypes(include="object").columns:
    unique_vals = laptops_clean[col].nunique()
    sample_vals = laptops_clean[col].dropna().unique()[:5]
    print(f"\n{col}  ({unique_vals} unique values)")
    print(f"  Sample: {list(sample_vals)}")
# Out:
# ...
# UNIQUE VALUES IN KEY COLUMNS — LAPTOPS CLEANED
# ...
#
# brand_name  (29 unique values)
#   Sample: ['Lenovo', 'Samsung', 'HP', 'MSI', 'Asus']
#
# model  (881 unique values)
#   Sample: ['Lenovo V15 G4 \u200e83CR000VIN Laptop (AMD Ryzen 7 7730U/ 16GB/ 512GB SSD/ Win11 Home)', 'Samsung Galaxy Book 4 NP750XGJ-LG4IN Laptop (13th Gen Intel Core i3-1315U/ 8GB/ 512GB SSD/ Win11)', 'HP 15-fc0154AU Laptop (AMD Ryzen 3 7320U/ 8GB/ 512GB SSD/ Win11 Home)', 'MSI Titan 18 HX Gaming Laptop (Intel Core Ultra 9-285HX / 32GB/ 1TB SSD/ Win11 Home/ RTX 5070)', 'Asus Vivobook 16X 2023 K3605ZC-MBN544WS Laptop (12th Gen Core i5/ 16GB/ 512GB SSD/ Win11/ 4GB RTX3050)']
#
# processor  (172 unique values)
#   Sample: ['7th Gen AMD Ryzen 7 7730U', '13th Gen Intel Core i3 1315U', '7th Gen AMD Ryzen 3 7320U', 'Intel Core Ultra 9 285HX', '12th Gen Intel Core i5 12500H']
#
# processor_brand  (6 unique values)
#   Sample: ['AMD', 'Intel', 'Apple', 'Qualcomm', 'MediaTek']
#
# iter  (16 unique values)
# ...
